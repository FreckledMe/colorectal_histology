# %%
import tensorflow as tf
from tensorflow import keras
import tensorflow_datasets as tfds
import numpy as np
from tensorflow.keras.models import Sequential
import matplotlib.pyplot as plt
import cv2
from tensorflow.keras import activations
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Dropout, concatenate, AveragePooling2D, Flatten, Dense

# %%
data,info = tfds.load(
    'colorectal_histology',
    split=['train'],
    shuffle_files=True,
    batch_size=-1,
    as_supervised=True,
    with_info=True)

# %%
info
# Out:
# tfds.core.DatasetInfo(
#     name='colorectal_histology',
#     full_name='colorectal_histology/2.0.0',
#     description="""
#     Classification of textures in colorectal cancer histology. Each example is a 150 x 150 x 3 RGB image of one of 8 classes.
#     """,
#     homepage='https://zenodo.org/record/53169#.XGZemKwzbmG',
#     data_path='C:\\Users\\justf\\tensorflow_datasets\\colorectal_histology\\2.0.0',
#     file_format=tfrecord,
#     download_size=246.14 MiB,
#     dataset_size=179.23 MiB,
#     features=FeaturesDict({
#         'filename': Text(shape=(), dtype=string),
#         'image': Image(shape=(150, 150, 3), dtype=uint8),
#         'label': ClassLabel(shape=(), dtype=int64, num_classes=8),
#     }),
#     supervised_keys=('image', 'label'),
#     disable_shuffling=False,
#     splits={
#         'train': <SplitInfo num_examples=5000, num_shards=2>,
#     },
#     citation="""@article{kather2016multi,
#       title={Multi-class texture analysis in colorectal cancer histology},
#       author={Kather, Jakob Nikolas and Weis, Cleo-Aron and Bianconi, Francesco and Melchers, Susanne M and Schad, Lothar R and Gaiser, Timo and Marx, Alexander and Z{"o}llner, Frank Gerrit},
#       journal={Scientific reports},
#       volume={6},
#       pages={27988},
#       year={2016},
#       publisher={Nature Publishing Group}
#     }""",
# )

# %%
images,labels = tfds.as_numpy(data[0])

# %%
def dataset_maker(img_data,labels):
    images = []
    for img in img_data:
        img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
        img = cv2.resize(img,dsize=(224,224),interpolation=cv2.INTER_AREA)
        img = img.astype('float32')
        img /= 255
        images.append(img)
    images = np.array(images)
    labels = labels.astype('uint32')
    return images,labels

# %%
images,labels = dataset_maker(images,labels)

# %%
train_ds = tf.data.Dataset.from_tensor_slices((images[:4000],labels[:4000])).batch(32)
test_ds = tf.data.Dataset.from_tensor_slices((images[4000:],labels[4000:])).batch(32)

# %% [markdown]
# ## GoogleNet from scratch

# %%
class InceptionModule(tf.keras.layers.Layer):
    def __init__(self, filters_1x1, filters_3x3_reduce, filters_3x3, filters_5x5_reduce, filters_5x5, filters_pool_proj):
        super(InceptionModule, self).__init__()
        
        self.conv1 = Conv2D(filters_1x1, kernel_size=(1, 1), padding='same', activation='relu')
        
        self.conv2_reduce = Conv2D(filters_3x3_reduce, kernel_size=(1, 1), padding='same', activation='relu')
        self.conv2 = Conv2D(filters_3x3, kernel_size=(3, 3), padding='same', activation='relu')
        
        self.conv3_reduce = Conv2D(filters_5x5_reduce, kernel_size=(1, 1), padding='same', activation='relu')
        self.conv3 = Conv2D(filters_5x5, kernel_size=(5, 5), padding='same', activation='relu')
        
        self.pool_proj = Conv2D(filters_pool_proj, kernel_size=(1, 1), padding='same', activation='relu')
        
    def call(self, inputs):
        conv1_out = self.conv1(inputs)
        
        conv2_reduce_out = self.conv2_reduce(inputs)
        conv2_out = self.conv2(conv2_reduce_out)
        
        conv3_reduce_out = self.conv3_reduce(inputs)
        conv3_out = self.conv3(conv3_reduce_out)
        
        pool_out = MaxPooling2D(pool_size=(3, 3), strides=(1, 1), padding='same')(inputs)
        pool_proj_out = self.pool_proj(pool_out)
        
        inception_out = concatenate([conv1_out, conv2_out, conv3_out, pool_proj_out], axis=-1)
        
        return inception_out
    
class GoogleNet(tf.keras.Model):
    def __init__(self, num_classes):
        super(GoogleNet, self).__init__()
        
        self.conv1 = Conv2D(64, kernel_size=(7, 7), strides=(2, 2), padding='same', activation='relu')
        self.max_pool1 = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), padding='same')
        
        self.conv2_reduce = Conv2D(64, kernel_size=(1, 1), padding='same', activation='relu')
        self.conv2 = Conv2D(192, kernel_size=(3, 3), padding='same', activation='relu')
        self.max_pool2 = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), padding='same')
        
        self.inception3a = InceptionModule(64, 96, 128, 16, 32, 32)
        self.inception3b = InceptionModule(128, 128, 192, 32, 96, 64)
        self.max_pool3 = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), padding='same')
        
        self.inception4a = InceptionModule(192, 96, 208, 16, 48, 64)
        self.inception4b = InceptionModule(160, 112, 224, 24, 64, 64)
        self.inception4c = InceptionModule(128, 128, 256, 24, 64, 64)
        self.inception4d = InceptionModule(112, 144, 288, 32, 64, 64)
        self.inception4e = InceptionModule(256, 160, 320, 32, 128, 128)
        self.max_pool4 = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), padding='same')
        
        self.inception5a = InceptionModule(256, 160, 320, 32, 128, 128)
        self.inception5b = InceptionModule(384, 192, 384, 48, 128, 128)
        
        self.avg_pool = AveragePooling2D(pool_size=(7, 7), strides=(1, 1), padding='valid')
        self.dropout = Dropout(0.4)
        self.fc1 = Dense(num_classes, activation='softmax')
        
    def call(self, inputs):
        x = self.conv1(inputs)
        x = self.max_pool1(x)
        
        x = self.conv2_reduce(x)
        x = self.conv2(x)
        x = self.max_pool2(x)
        
        x = self.inception3a(x)
        x = self.inception3b(x)
        x = self.max_pool3(x)
        
        x = self.inception4a(x)
        x = self.inception4b(x)
        x = self.inception4c(x)
        x = self.inception4d(x)
        x = self.inception4e(x)
        x = self.max_pool4(x)
        
        x = self.inception5a(x)
        x = self.inception5b(x)

        x = self.avg_pool(x)
        x = self.dropout(x)
        
        return self.fc1(x)

# %%
model = GoogleNet(num_classes=8)

# %%
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

optimizer = tf.keras.optimizers.Adam()

# %%
train_loss = tf.keras.metrics.Mean(name='train_loss')
train_accuracy = tf.keras.metrics.SparseCategoricalAccuracy(name='train_accuracy')

test_loss = tf.keras.metrics.Mean(name='test_loss')
test_accuracy = tf.keras.metrics.SparseCategoricalAccuracy(name='test_accuracy')

# %%
@tf.function
def train_step(images, labels):
    with tf.GradientTape() as tape:
        predictions = model(images, training=True)
        loss = loss_object(labels, predictions)
    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))
    
    train_loss(loss)
    train_accuracy(labels, predictions)

# %%
@tf.function
def test_step(images, labels):
    predictions = model(images, training=False)
    t_loss = loss_object(labels, predictions)

    test_loss(t_loss)
    test_accuracy(labels, predictions)

# %%
EPOCHS = 5
with tf.device('/device:GPU:0'):
    for epoch in range(EPOCHS):
        train_loss.reset_states()
        train_accuracy.reset_states()
        test_loss.reset_states()
        test_accuracy.reset_states()

        for images, labels in train_ds:
            train_step(images, labels)
        for test_images, test_labels in test_ds:
            test_step(test_images, test_labels)
        print(
            f'Epoch {epoch + 1}, '
            f'Loss: {train_loss.result()}, '
            f'Accuracy: {train_accuracy.result() * 100}, '
            f'Test Loss: {test_loss.result()}, '
            f'Test Accuracy: {test_accuracy.result() * 100}'
        )
# Out:
# Epoch 1, Loss: 1.853042483329773, Accuracy: 12.642969131469727, Test Loss: 1.7231708765029907, Test Accuracy: 12.974722862243652
# Epoch 2, Loss: 1.4905524253845215, Accuracy: 13.198436737060547, Test Loss: 1.4757370948791504, Test Accuracy: 13.60035228729248
# Epoch 3, Loss: 1.3746355772018433, Accuracy: 13.424219131469727, Test Loss: 1.326932430267334, Test Accuracy: 13.60035228729248
# Epoch 4, Loss: 1.371283769607544, Accuracy: 13.34218692779541, Test Loss: 1.368717908859253, Test Accuracy: 13.628646850585938
# Epoch 5, Loss: 1.2902132272720337, Accuracy: 13.383594512939453, Test Loss: 1.2748913764953613, Test Accuracy: 13.616071701049805

# %%
model.summary()
# Out:
# Model: "google_net_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_114 (Conv2D)         multiple                  9472
#
#  max_pooling2d_8 (MaxPooling  multiple                 0
#  2D)
#
#  conv2d_115 (Conv2D)         multiple                  4160
#
#  conv2d_116 (Conv2D)         multiple                  110784
#
#  max_pooling2d_9 (MaxPooling  multiple                 0
#  2D)
#
#  inception_module_18 (Incept  multiple                 163696
#  ionModule)
#
#  inception_module_19 (Incept  multiple                 388736
#  ionModule)
#
#  max_pooling2d_10 (MaxPoolin  multiple                 0
#  g2D)
#
#  inception_module_20 (Incept  multiple                 376176
#  ionModule)
#
#  inception_module_21 (Incept  multiple                 449160
#  ionModule)
#
#  inception_module_22 (Incept  multiple                 510104
#  ionModule)
#
#  inception_module_23 (Incept  multiple                 605376
#  ionModule)
#
#  inception_module_24 (Incept  multiple                 868352
#  ionModule)
#
#  max_pooling2d_11 (MaxPoolin  multiple                 0
#  g2D)
#
#  inception_module_25 (Incept  multiple                 1043456
#  ionModule)
#
#  inception_module_26 (Incept  multiple                 1444080
#  ionModule)
#
#  average_pooling2d_2 (Averag  multiple                 0
#  ePooling2D)
#
#  dropout_2 (Dropout)         multiple                  0
#
#  dense_2 (Dense)             multiple                  8200
#
# =================================================================
# Total params: 5,981,752
# Trainable params: 5,981,752
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.save('scratch/')
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, conv2d_117_layer_call_fn, conv2d_117_layer_call_and_return_conditional_losses while saving (showing 5 of 165). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: scratch/assets
# INFO:tensorflow:Assets written to: scratch/assets

# %% [markdown]
# ## Transfer learning with Inception

# %%
inception = keras.applications.InceptionV3(input_shape=(224,224,3),include_top=False)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 19s 0us/step

# %%
inception.trainable=False

# %%
inception.summary()
# Out:
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d_171 (Conv2D)            (None, 111, 111, 32  864         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 111, 111, 32  96         ['conv2d_171[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 111, 111, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_172 (Conv2D)            (None, 109, 109, 32  9216        ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 109, 109, 32  96         ['conv2d_172[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 109, 109, 32  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  conv2d_173 (Conv2D)            (None, 109, 109, 64  18432       ['activation_1[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 109, 109, 64  192        ['conv2d_173[0][0]']
#  rmalization)                   )
#
#  activation_2 (Activation)      (None, 109, 109, 64  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  max_pooling2d_12 (MaxPooling2D  (None, 54, 54, 64)  0           ['activation_2[0][0]']
#  )
#
#  conv2d_174 (Conv2D)            (None, 54, 54, 80)   5120        ['max_pooling2d_12[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 54, 54, 80)  240         ['conv2d_174[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 54, 54, 80)   0           ['batch_normalization_3[0][0]']
#
#  conv2d_175 (Conv2D)            (None, 52, 52, 192)  138240      ['activation_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 52, 52, 192)  576        ['conv2d_175[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 52, 52, 192)  0           ['batch_normalization_4[0][0]']
#
#  max_pooling2d_13 (MaxPooling2D  (None, 25, 25, 192)  0          ['activation_4[0][0]']
#  )
#
#  conv2d_179 (Conv2D)            (None, 25, 25, 64)   12288       ['max_pooling2d_13[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 25, 25, 64)  192         ['conv2d_179[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 25, 25, 64)   0           ['batch_normalization_8[0][0]']
#
#  conv2d_177 (Conv2D)            (None, 25, 25, 48)   9216        ['max_pooling2d_13[0][0]']
#
#  conv2d_180 (Conv2D)            (None, 25, 25, 96)   55296       ['activation_8[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 25, 25, 48)  144         ['conv2d_177[0][0]']
#  rmalization)
#
#  batch_normalization_9 (BatchNo  (None, 25, 25, 96)  288         ['conv2d_180[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 25, 25, 48)   0           ['batch_normalization_6[0][0]']
#
#  activation_9 (Activation)      (None, 25, 25, 96)   0           ['batch_normalization_9[0][0]']
#
#  average_pooling2d_3 (AveragePo  (None, 25, 25, 192)  0          ['max_pooling2d_13[0][0]']
#  oling2D)
#
#  conv2d_176 (Conv2D)            (None, 25, 25, 64)   12288       ['max_pooling2d_13[0][0]']
#
#  conv2d_178 (Conv2D)            (None, 25, 25, 64)   76800       ['activation_6[0][0]']
#
#  conv2d_181 (Conv2D)            (None, 25, 25, 96)   82944       ['activation_9[0][0]']
#
#  conv2d_182 (Conv2D)            (None, 25, 25, 32)   6144        ['average_pooling2d_3[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 25, 25, 64)  192         ['conv2d_176[0][0]']
#  rmalization)
#
#  batch_normalization_7 (BatchNo  (None, 25, 25, 64)  192         ['conv2d_178[0][0]']
#  rmalization)
#
#  batch_normalization_10 (BatchN  (None, 25, 25, 96)  288         ['conv2d_181[0][0]']
#  ormalization)
#
#  batch_normalization_11 (BatchN  (None, 25, 25, 32)  96          ['conv2d_182[0][0]']
#  ormalization)
#
#  activation_5 (Activation)      (None, 25, 25, 64)   0           ['batch_normalization_5[0][0]']
#
#  activation_7 (Activation)      (None, 25, 25, 64)   0           ['batch_normalization_7[0][0]']
#
#  activation_10 (Activation)     (None, 25, 25, 96)   0           ['batch_normalization_10[0][0]']
#
#  activation_11 (Activation)     (None, 25, 25, 32)   0           ['batch_normalization_11[0][0]']
#
#  mixed0 (Concatenate)           (None, 25, 25, 256)  0           ['activation_5[0][0]',
#                                                                   'activation_7[0][0]',
#                                                                   'activation_10[0][0]',
#                                                                   'activation_11[0][0]']
#
#  conv2d_186 (Conv2D)            (None, 25, 25, 64)   16384       ['mixed0[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 25, 25, 64)  192         ['conv2d_186[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 25, 25, 64)   0           ['batch_normalization_15[0][0]']
#
#  conv2d_184 (Conv2D)            (None, 25, 25, 48)   12288       ['mixed0[0][0]']
#
#  conv2d_187 (Conv2D)            (None, 25, 25, 96)   55296       ['activation_15[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 25, 25, 48)  144         ['conv2d_184[0][0]']
#  ormalization)
#
#  batch_normalization_16 (BatchN  (None, 25, 25, 96)  288         ['conv2d_187[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 25, 25, 48)   0           ['batch_normalization_13[0][0]']
#
#  activation_16 (Activation)     (None, 25, 25, 96)   0           ['batch_normalization_16[0][0]']
#
#  average_pooling2d_4 (AveragePo  (None, 25, 25, 256)  0          ['mixed0[0][0]']
#  oling2D)
#
#  conv2d_183 (Conv2D)            (None, 25, 25, 64)   16384       ['mixed0[0][0]']
#
#  conv2d_185 (Conv2D)            (None, 25, 25, 64)   76800       ['activation_13[0][0]']
#
#  conv2d_188 (Conv2D)            (None, 25, 25, 96)   82944       ['activation_16[0][0]']
#
#  conv2d_189 (Conv2D)            (None, 25, 25, 64)   16384       ['average_pooling2d_4[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 25, 25, 64)  192         ['conv2d_183[0][0]']
#  ormalization)
#
#  batch_normalization_14 (BatchN  (None, 25, 25, 64)  192         ['conv2d_185[0][0]']
#  ormalization)
#
#  batch_normalization_17 (BatchN  (None, 25, 25, 96)  288         ['conv2d_188[0][0]']
#  ormalization)
#
#  batch_normalization_18 (BatchN  (None, 25, 25, 64)  192         ['conv2d_189[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 25, 25, 64)   0           ['batch_normalization_12[0][0]']
#
#  activation_14 (Activation)     (None, 25, 25, 64)   0           ['batch_normalization_14[0][0]']
#
#  activation_17 (Activation)     (None, 25, 25, 96)   0           ['batch_normalization_17[0][0]']
#
#  activation_18 (Activation)     (None, 25, 25, 64)   0           ['batch_normalization_18[0][0]']
#
#  mixed1 (Concatenate)           (None, 25, 25, 288)  0           ['activation_12[0][0]',
#                                                                   'activation_14[0][0]',
#                                                                   'activation_17[0][0]',
#                                                                   'activation_18[0][0]']
#
#  conv2d_193 (Conv2D)            (None, 25, 25, 64)   18432       ['mixed1[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 25, 25, 64)  192         ['conv2d_193[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 25, 25, 64)   0           ['batch_normalization_22[0][0]']
#
#  conv2d_191 (Conv2D)            (None, 25, 25, 48)   13824       ['mixed1[0][0]']
#
#  conv2d_194 (Conv2D)            (None, 25, 25, 96)   55296       ['activation_22[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 25, 25, 48)  144         ['conv2d_191[0][0]']
#  ormalization)
#
#  batch_normalization_23 (BatchN  (None, 25, 25, 96)  288         ['conv2d_194[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 25, 25, 48)   0           ['batch_normalization_20[0][0]']
#
#  activation_23 (Activation)     (None, 25, 25, 96)   0           ['batch_normalization_23[0][0]']
#
#  average_pooling2d_5 (AveragePo  (None, 25, 25, 288)  0          ['mixed1[0][0]']
#  oling2D)
#
#  conv2d_190 (Conv2D)            (None, 25, 25, 64)   18432       ['mixed1[0][0]']
#
#  conv2d_192 (Conv2D)            (None, 25, 25, 64)   76800       ['activation_20[0][0]']
#
#  conv2d_195 (Conv2D)            (None, 25, 25, 96)   82944       ['activation_23[0][0]']
#
#  conv2d_196 (Conv2D)            (None, 25, 25, 64)   18432       ['average_pooling2d_5[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 25, 25, 64)  192         ['conv2d_190[0][0]']
#  ormalization)
#
#  batch_normalization_21 (BatchN  (None, 25, 25, 64)  192         ['conv2d_192[0][0]']
#  ormalization)
#
#  batch_normalization_24 (BatchN  (None, 25, 25, 96)  288         ['conv2d_195[0][0]']
#  ormalization)
#
#  batch_normalization_25 (BatchN  (None, 25, 25, 64)  192         ['conv2d_196[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 25, 25, 64)   0           ['batch_normalization_19[0][0]']
#
#  activation_21 (Activation)     (None, 25, 25, 64)   0           ['batch_normalization_21[0][0]']
#
#  activation_24 (Activation)     (None, 25, 25, 96)   0           ['batch_normalization_24[0][0]']
#
#  activation_25 (Activation)     (None, 25, 25, 64)   0           ['batch_normalization_25[0][0]']
#
#  mixed2 (Concatenate)           (None, 25, 25, 288)  0           ['activation_19[0][0]',
#                                                                   'activation_21[0][0]',
#                                                                   'activation_24[0][0]',
#                                                                   'activation_25[0][0]']
#
#  conv2d_198 (Conv2D)            (None, 25, 25, 64)   18432       ['mixed2[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 25, 25, 64)  192         ['conv2d_198[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 25, 25, 64)   0           ['batch_normalization_27[0][0]']
#
#  conv2d_199 (Conv2D)            (None, 25, 25, 96)   55296       ['activation_27[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 25, 25, 96)  288         ['conv2d_199[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 25, 25, 96)   0           ['batch_normalization_28[0][0]']
#
#  conv2d_197 (Conv2D)            (None, 12, 12, 384)  995328      ['mixed2[0][0]']
#
#  conv2d_200 (Conv2D)            (None, 12, 12, 96)   82944       ['activation_28[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 12, 12, 384)  1152       ['conv2d_197[0][0]']
#  ormalization)
#
#  batch_normalization_29 (BatchN  (None, 12, 12, 96)  288         ['conv2d_200[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 12, 12, 384)  0           ['batch_normalization_26[0][0]']
#
#  activation_29 (Activation)     (None, 12, 12, 96)   0           ['batch_normalization_29[0][0]']
#
#  max_pooling2d_14 (MaxPooling2D  (None, 12, 12, 288)  0          ['mixed2[0][0]']
#  )
#
#  mixed3 (Concatenate)           (None, 12, 12, 768)  0           ['activation_26[0][0]',
#                                                                   'activation_29[0][0]',
#                                                                   'max_pooling2d_14[0][0]']
#
#  conv2d_205 (Conv2D)            (None, 12, 12, 128)  98304       ['mixed3[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 12, 12, 128)  384        ['conv2d_205[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 12, 12, 128)  0           ['batch_normalization_34[0][0]']
#
#  conv2d_206 (Conv2D)            (None, 12, 12, 128)  114688      ['activation_34[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 12, 12, 128)  384        ['conv2d_206[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 12, 12, 128)  0           ['batch_normalization_35[0][0]']
#
#  conv2d_202 (Conv2D)            (None, 12, 12, 128)  98304       ['mixed3[0][0]']
#
#  conv2d_207 (Conv2D)            (None, 12, 12, 128)  114688      ['activation_35[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 12, 12, 128)  384        ['conv2d_202[0][0]']
#  ormalization)
#
#  batch_normalization_36 (BatchN  (None, 12, 12, 128)  384        ['conv2d_207[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 12, 12, 128)  0           ['batch_normalization_31[0][0]']
#
#  activation_36 (Activation)     (None, 12, 12, 128)  0           ['batch_normalization_36[0][0]']
#
#  conv2d_203 (Conv2D)            (None, 12, 12, 128)  114688      ['activation_31[0][0]']
#
#  conv2d_208 (Conv2D)            (None, 12, 12, 128)  114688      ['activation_36[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 12, 12, 128)  384        ['conv2d_203[0][0]']
#  ormalization)
#
#  batch_normalization_37 (BatchN  (None, 12, 12, 128)  384        ['conv2d_208[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 12, 12, 128)  0           ['batch_normalization_32[0][0]']
#
#  activation_37 (Activation)     (None, 12, 12, 128)  0           ['batch_normalization_37[0][0]']
#
#  average_pooling2d_6 (AveragePo  (None, 12, 12, 768)  0          ['mixed3[0][0]']
#  oling2D)
#
#  conv2d_201 (Conv2D)            (None, 12, 12, 192)  147456      ['mixed3[0][0]']
#
#  conv2d_204 (Conv2D)            (None, 12, 12, 192)  172032      ['activation_32[0][0]']
#
#  conv2d_209 (Conv2D)            (None, 12, 12, 192)  172032      ['activation_37[0][0]']
#
#  conv2d_210 (Conv2D)            (None, 12, 12, 192)  147456      ['average_pooling2d_6[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 12, 12, 192)  576        ['conv2d_201[0][0]']
#  ormalization)
#
#  batch_normalization_33 (BatchN  (None, 12, 12, 192)  576        ['conv2d_204[0][0]']
#  ormalization)
#
#  batch_normalization_38 (BatchN  (None, 12, 12, 192)  576        ['conv2d_209[0][0]']
#  ormalization)
#
#  batch_normalization_39 (BatchN  (None, 12, 12, 192)  576        ['conv2d_210[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 12, 12, 192)  0           ['batch_normalization_30[0][0]']
#
#  activation_33 (Activation)     (None, 12, 12, 192)  0           ['batch_normalization_33[0][0]']
#
#  activation_38 (Activation)     (None, 12, 12, 192)  0           ['batch_normalization_38[0][0]']
#
#  activation_39 (Activation)     (None, 12, 12, 192)  0           ['batch_normalization_39[0][0]']
#
#  mixed4 (Concatenate)           (None, 12, 12, 768)  0           ['activation_30[0][0]',
#                                                                   'activation_33[0][0]',
#                                                                   'activation_38[0][0]',
#                                                                   'activation_39[0][0]']
#
#  conv2d_215 (Conv2D)            (None, 12, 12, 160)  122880      ['mixed4[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 12, 12, 160)  480        ['conv2d_215[0][0]']
#  ormalization)
#
#  activation_44 (Activation)     (None, 12, 12, 160)  0           ['batch_normalization_44[0][0]']
#
#  conv2d_216 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_44[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 12, 12, 160)  480        ['conv2d_216[0][0]']
#  ormalization)
#
#  activation_45 (Activation)     (None, 12, 12, 160)  0           ['batch_normalization_45[0][0]']
#
#  conv2d_212 (Conv2D)            (None, 12, 12, 160)  122880      ['mixed4[0][0]']
#
#  conv2d_217 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_45[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 12, 12, 160)  480        ['conv2d_212[0][0]']
#  ormalization)
#
#  batch_normalization_46 (BatchN  (None, 12, 12, 160)  480        ['conv2d_217[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 12, 12, 160)  0           ['batch_normalization_41[0][0]']
#
#  activation_46 (Activation)     (None, 12, 12, 160)  0           ['batch_normalization_46[0][0]']
#
#  conv2d_213 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_41[0][0]']
#
#  conv2d_218 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_46[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 12, 12, 160)  480        ['conv2d_213[0][0]']
#  ormalization)
#
#  batch_normalization_47 (BatchN  (None, 12, 12, 160)  480        ['conv2d_218[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 12, 12, 160)  0           ['batch_normalization_42[0][0]']
#
#  activation_47 (Activation)     (None, 12, 12, 160)  0           ['batch_normalization_47[0][0]']
#
#  average_pooling2d_7 (AveragePo  (None, 12, 12, 768)  0          ['mixed4[0][0]']
#  oling2D)
#
#  conv2d_211 (Conv2D)            (None, 12, 12, 192)  147456      ['mixed4[0][0]']
#
#  conv2d_214 (Conv2D)            (None, 12, 12, 192)  215040      ['activation_42[0][0]']
#
#  conv2d_219 (Conv2D)            (None, 12, 12, 192)  215040      ['activation_47[0][0]']
#
#  conv2d_220 (Conv2D)            (None, 12, 12, 192)  147456      ['average_pooling2d_7[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 12, 12, 192)  576        ['conv2d_211[0][0]']
#  ormalization)
#
#  batch_normalization_43 (BatchN  (None, 12, 12, 192)  576        ['conv2d_214[0][0]']
#  ormalization)
#
#  batch_normalization_48 (BatchN  (None, 12, 12, 192)  576        ['conv2d_219[0][0]']
#  ormalization)
#
#  batch_normalization_49 (BatchN  (None, 12, 12, 192)  576        ['conv2d_220[0][0]']
#  ormalization)
#
#  activation_40 (Activation)     (None, 12, 12, 192)  0           ['batch_normalization_40[0][0]']
#
#  activation_43 (Activation)     (None, 12, 12, 192)  0           ['batch_normalization_43[0][0]']
#
#  activation_48 (Activation)     (None, 12, 12, 192)  0           ['batch_normalization_48[0][0]']
#
#  activation_49 (Activation)     (None, 12, 12, 192)  0           ['batch_normalization_49[0][0]']
#
#  mixed5 (Concatenate)           (None, 12, 12, 768)  0           ['activation_40[0][0]',
#                                                                   'activation_43[0][0]',
#                                                                   'activation_48[0][0]',
#                                                                   'activation_49[0][0]']
#
#  conv2d_225 (Conv2D)            (None, 12, 12, 160)  122880      ['mixed5[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 12, 12, 160)  480        ['conv2d_225[0][0]']
#  ormalization)
#
#  activation_54 (Activation)     (None, 12, 12, 160)  0           ['batch_normalization_54[0][0]']
#
#  conv2d_226 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_54[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 12, 12, 160)  480        ['conv2d_226[0][0]']
#  ormalization)
#
#  activation_55 (Activation)     (None, 12, 12, 160)  0           ['batch_normalization_55[0][0]']
#
#  conv2d_222 (Conv2D)            (None, 12, 12, 160)  122880      ['mixed5[0][0]']
#
#  conv2d_227 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_55[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 12, 12, 160)  480        ['conv2d_222[0][0]']
#  ormalization)
#
#  batch_normalization_56 (BatchN  (None, 12, 12, 160)  480        ['conv2d_227[0][0]']
#  ormalization)
#
#  activation_51 (Activation)     (None, 12, 12, 160)  0           ['batch_normalization_51[0][0]']
#
#  activation_56 (Activation)     (None, 12, 12, 160)  0           ['batch_normalization_56[0][0]']
#
#  conv2d_223 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_51[0][0]']
#
#  conv2d_228 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_56[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 12, 12, 160)  480        ['conv2d_223[0][0]']
#  ormalization)
#
#  batch_normalization_57 (BatchN  (None, 12, 12, 160)  480        ['conv2d_228[0][0]']
#  ormalization)
#
#  activation_52 (Activation)     (None, 12, 12, 160)  0           ['batch_normalization_52[0][0]']
#
#  activation_57 (Activation)     (None, 12, 12, 160)  0           ['batch_normalization_57[0][0]']
#
#  average_pooling2d_8 (AveragePo  (None, 12, 12, 768)  0          ['mixed5[0][0]']
#  oling2D)
#
#  conv2d_221 (Conv2D)            (None, 12, 12, 192)  147456      ['mixed5[0][0]']
#
#  conv2d_224 (Conv2D)            (None, 12, 12, 192)  215040      ['activation_52[0][0]']
#
#  conv2d_229 (Conv2D)            (None, 12, 12, 192)  215040      ['activation_57[0][0]']
#
#  conv2d_230 (Conv2D)            (None, 12, 12, 192)  147456      ['average_pooling2d_8[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 12, 12, 192)  576        ['conv2d_221[0][0]']
#  ormalization)
#
#  batch_normalization_53 (BatchN  (None, 12, 12, 192)  576        ['conv2d_224[0][0]']
#  ormalization)
#
#  batch_normalization_58 (BatchN  (None, 12, 12, 192)  576        ['conv2d_229[0][0]']
#  ormalization)
#
#  batch_normalization_59 (BatchN  (None, 12, 12, 192)  576        ['conv2d_230[0][0]']
#  ormalization)
#
#  activation_50 (Activation)     (None, 12, 12, 192)  0           ['batch_normalization_50[0][0]']
#
#  activation_53 (Activation)     (None, 12, 12, 192)  0           ['batch_normalization_53[0][0]']
#
# ...
#  mixed8 (Concatenate)           (None, 5, 5, 1280)   0           ['activation_71[0][0]',
#                                                                   'activation_75[0][0]',
#                                                                   'max_pooling2d_15[0][0]']
#
#  conv2d_251 (Conv2D)            (None, 5, 5, 448)    573440      ['mixed8[0][0]']
#
#  batch_normalization_80 (BatchN  (None, 5, 5, 448)   1344        ['conv2d_251[0][0]']
#  ormalization)
#
#  activation_80 (Activation)     (None, 5, 5, 448)    0           ['batch_normalization_80[0][0]']
#
#  conv2d_248 (Conv2D)            (None, 5, 5, 384)    491520      ['mixed8[0][0]']
#
#  conv2d_252 (Conv2D)            (None, 5, 5, 384)    1548288     ['activation_80[0][0]']
#
#  batch_normalization_77 (BatchN  (None, 5, 5, 384)   1152        ['conv2d_248[0][0]']
#  ormalization)
#
#  batch_normalization_81 (BatchN  (None, 5, 5, 384)   1152        ['conv2d_252[0][0]']
#  ormalization)
#
#  activation_77 (Activation)     (None, 5, 5, 384)    0           ['batch_normalization_77[0][0]']
#
#  activation_81 (Activation)     (None, 5, 5, 384)    0           ['batch_normalization_81[0][0]']
#
#  conv2d_249 (Conv2D)            (None, 5, 5, 384)    442368      ['activation_77[0][0]']
#
#  conv2d_250 (Conv2D)            (None, 5, 5, 384)    442368      ['activation_77[0][0]']
#
#  conv2d_253 (Conv2D)            (None, 5, 5, 384)    442368      ['activation_81[0][0]']
#
#  conv2d_254 (Conv2D)            (None, 5, 5, 384)    442368      ['activation_81[0][0]']
#
#  average_pooling2d_10 (AverageP  (None, 5, 5, 1280)  0           ['mixed8[0][0]']
#  ooling2D)
#
#  conv2d_247 (Conv2D)            (None, 5, 5, 320)    409600      ['mixed8[0][0]']
#
#  batch_normalization_78 (BatchN  (None, 5, 5, 384)   1152        ['conv2d_249[0][0]']
#  ormalization)
#
#  batch_normalization_79 (BatchN  (None, 5, 5, 384)   1152        ['conv2d_250[0][0]']
#  ormalization)
#
#  batch_normalization_82 (BatchN  (None, 5, 5, 384)   1152        ['conv2d_253[0][0]']
#  ormalization)
#
#  batch_normalization_83 (BatchN  (None, 5, 5, 384)   1152        ['conv2d_254[0][0]']
#  ormalization)
#
#  conv2d_255 (Conv2D)            (None, 5, 5, 192)    245760      ['average_pooling2d_10[0][0]']
#
#  batch_normalization_76 (BatchN  (None, 5, 5, 320)   960         ['conv2d_247[0][0]']
#  ormalization)
#
#  activation_78 (Activation)     (None, 5, 5, 384)    0           ['batch_normalization_78[0][0]']
#
#  activation_79 (Activation)     (None, 5, 5, 384)    0           ['batch_normalization_79[0][0]']
#
#  activation_82 (Activation)     (None, 5, 5, 384)    0           ['batch_normalization_82[0][0]']
#
#  activation_83 (Activation)     (None, 5, 5, 384)    0           ['batch_normalization_83[0][0]']
#
#  batch_normalization_84 (BatchN  (None, 5, 5, 192)   576         ['conv2d_255[0][0]']
#  ormalization)
#
#  activation_76 (Activation)     (None, 5, 5, 320)    0           ['batch_normalization_76[0][0]']
#
#  mixed9_0 (Concatenate)         (None, 5, 5, 768)    0           ['activation_78[0][0]',
#                                                                   'activation_79[0][0]']
#
#  concatenate (Concatenate)      (None, 5, 5, 768)    0           ['activation_82[0][0]',
#                                                                   'activation_83[0][0]']
#
#  activation_84 (Activation)     (None, 5, 5, 192)    0           ['batch_normalization_84[0][0]']
#
#  mixed9 (Concatenate)           (None, 5, 5, 2048)   0           ['activation_76[0][0]',
#                                                                   'mixed9_0[0][0]',
#                                                                   'concatenate[0][0]',
#                                                                   'activation_84[0][0]']
#
#  conv2d_260 (Conv2D)            (None, 5, 5, 448)    917504      ['mixed9[0][0]']
#
#  batch_normalization_89 (BatchN  (None, 5, 5, 448)   1344        ['conv2d_260[0][0]']
#  ormalization)
#
#  activation_89 (Activation)     (None, 5, 5, 448)    0           ['batch_normalization_89[0][0]']
#
#  conv2d_257 (Conv2D)            (None, 5, 5, 384)    786432      ['mixed9[0][0]']
#
#  conv2d_261 (Conv2D)            (None, 5, 5, 384)    1548288     ['activation_89[0][0]']
#
#  batch_normalization_86 (BatchN  (None, 5, 5, 384)   1152        ['conv2d_257[0][0]']
#  ormalization)
#
#  batch_normalization_90 (BatchN  (None, 5, 5, 384)   1152        ['conv2d_261[0][0]']
#  ormalization)
#
#  activation_86 (Activation)     (None, 5, 5, 384)    0           ['batch_normalization_86[0][0]']
#
#  activation_90 (Activation)     (None, 5, 5, 384)    0           ['batch_normalization_90[0][0]']
#
#  conv2d_258 (Conv2D)            (None, 5, 5, 384)    442368      ['activation_86[0][0]']
#
#  conv2d_259 (Conv2D)            (None, 5, 5, 384)    442368      ['activation_86[0][0]']
#
#  conv2d_262 (Conv2D)            (None, 5, 5, 384)    442368      ['activation_90[0][0]']
#
#  conv2d_263 (Conv2D)            (None, 5, 5, 384)    442368      ['activation_90[0][0]']
#
#  average_pooling2d_11 (AverageP  (None, 5, 5, 2048)  0           ['mixed9[0][0]']
#  ooling2D)
#
#  conv2d_256 (Conv2D)            (None, 5, 5, 320)    655360      ['mixed9[0][0]']
#
#  batch_normalization_87 (BatchN  (None, 5, 5, 384)   1152        ['conv2d_258[0][0]']
#  ormalization)
#
#  batch_normalization_88 (BatchN  (None, 5, 5, 384)   1152        ['conv2d_259[0][0]']
#  ormalization)
#
#  batch_normalization_91 (BatchN  (None, 5, 5, 384)   1152        ['conv2d_262[0][0]']
#  ormalization)
#
#  batch_normalization_92 (BatchN  (None, 5, 5, 384)   1152        ['conv2d_263[0][0]']
#  ormalization)
#
#  conv2d_264 (Conv2D)            (None, 5, 5, 192)    393216      ['average_pooling2d_11[0][0]']
#
#  batch_normalization_85 (BatchN  (None, 5, 5, 320)   960         ['conv2d_256[0][0]']
#  ormalization)
#
#  activation_87 (Activation)     (None, 5, 5, 384)    0           ['batch_normalization_87[0][0]']
#
#  activation_88 (Activation)     (None, 5, 5, 384)    0           ['batch_normalization_88[0][0]']
#
#  activation_91 (Activation)     (None, 5, 5, 384)    0           ['batch_normalization_91[0][0]']
#
#  activation_92 (Activation)     (None, 5, 5, 384)    0           ['batch_normalization_92[0][0]']
#
#  batch_normalization_93 (BatchN  (None, 5, 5, 192)   576         ['conv2d_264[0][0]']
#  ormalization)
#
#  activation_85 (Activation)     (None, 5, 5, 320)    0           ['batch_normalization_85[0][0]']
#
#  mixed9_1 (Concatenate)         (None, 5, 5, 768)    0           ['activation_87[0][0]',
#                                                                   'activation_88[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 5, 5, 768)    0           ['activation_91[0][0]',
#                                                                   'activation_92[0][0]']
#
#  activation_93 (Activation)     (None, 5, 5, 192)    0           ['batch_normalization_93[0][0]']
#
#  mixed10 (Concatenate)          (None, 5, 5, 2048)   0           ['activation_85[0][0]',
#                                                                   'mixed9_1[0][0]',
#                                                                   'concatenate_1[0][0]',
#                                                                   'activation_93[0][0]']
#
# ==================================================================================================
# Total params: 21,802,784
# Trainable params: 0
# Non-trainable params: 21,802,784
# __________________________________________________________________________________________________

# %%
with tf.device('/device:CPU:0'):
    in_model = Sequential([
        inception,
        keras.layers.Flatten(),
        keras.layers.Dense(4096,activation=activations.relu),
        keras.layers.Dense(2048,activation=activations.relu),
        keras.layers.Dense(1000,activation=activations.relu),
        keras.layers.Dense(100,activation=activations.relu),
        keras.layers.Dense(8,activation=activations.softmax)])

# %%
in_model.compile(optimizer=keras.optimizers.Adam(),
                 loss=keras.losses.SparseCategoricalCrossentropy(),
                 metrics=keras.metrics.SparseCategoricalAccuracy())

# %%
my_callbacks = [
    tf.keras.callbacks.EarlyStopping(patience=2),
    tf.keras.callbacks.ModelCheckpoint(filepath='saved_model/model.{epoch:02d}-{val_loss:.2f}.h5'),
    tf.keras.callbacks.TensorBoard(log_dir='./logs'),
]
with tf.device('/device:CPU:0'):
    in_model.fit(
        train_ds,
        epochs=5,
        callbacks=my_callbacks,
        verbose = 1,
        validation_data = test_ds)
# Out:
# Epoch 1/5
# 125/125 [==============================] - 289s 2s/step - loss: 5.2830 - sparse_categorical_accuracy: 0.6165 - val_loss: 0.5192 - val_sparse_categorical_accuracy: 0.8300
# Epoch 2/5
# 125/125 [==============================] - 229s 2s/step - loss: 0.4006 - sparse_categorical_accuracy: 0.8670 - val_loss: 0.5157 - val_sparse_categorical_accuracy: 0.8630
# Epoch 3/5
# 125/125 [==============================] - 219s 2s/step - loss: 0.3050 - sparse_categorical_accuracy: 0.9015 - val_loss: 0.8312 - val_sparse_categorical_accuracy: 0.8130
# Epoch 4/5
# 125/125 [==============================] - 213s 2s/step - loss: 0.2222 - sparse_categorical_accuracy: 0.9215 - val_loss: 0.5319 - val_sparse_categorical_accuracy: 0.8690

# %%
with tf.device('/device:CPU:0'):
    in_model.evaluate(test_ds)
# Out:
# 32/32 [==============================] - 27s 830ms/step - loss: 0.5319 - sparse_categorical_accuracy: 0.8690
